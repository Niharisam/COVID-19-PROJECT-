# %% [markdown]
# # Problem for  Covid-19 Data Analysis Project Using python

# %% [markdown]
# ### Dataset link:

# %%
Url = "https://raw.githubusercontent.com/SR1608/Datasets/main/covid-data.csv"

# %% [markdown]
# # 1.Importing the dataset using Pandas from aove mention url

# %%
#importing required libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import os
import pandas as pd
os.chdir("e:\ ")
data = pd.read_csv("covidtest.csv")
data
# Out:
#       iso_code continent       location      date  total_cases  new_cases  \
# 0          AFG      Asia    Afghanistan  31/12/19          NaN        0.0
# 1          AFG      Asia    Afghanistan  01/01/20          NaN        0.0
# 2          AFG      Asia    Afghanistan  02/01/20          NaN        0.0
# 3          AFG      Asia    Afghanistan  03/01/20          NaN        0.0
# 4          AFG      Asia    Afghanistan  04/01/20          NaN        0.0
# ...        ...       ...            ...       ...          ...        ...
# 57389      NaN       NaN  International  13/11/20        696.0        NaN
# 57390      NaN       NaN  International  14/11/20        696.0        NaN
# 57391      NaN       NaN  International  15/11/20        696.0        NaN
# 57392      NaN       NaN  International  16/11/20        696.0        NaN
# 57393      NaN       NaN  International  17/11/20        696.0        NaN
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %% [markdown]
# # 2.High  Level Data Understanding:

# %% [markdown]
# ## a.Find no.of Rows & Columns in the dataset

# %%
print("number of rows:",data.shape[0] ,"\nnumbers of column:",data.shape[1])
# Out:
# number of rows: 57394
# numbers of column: 49

# %% [markdown]
# ## b.Data Types of columns

# %%
print("data types of columns:\n",data.dtypes)
# Out:
# data types of columns:
#  iso_code                               object
# continent                              object
# location                               object
# date                                   object
# total_cases                           float64
# new_cases                             float64
# new_cases_smoothed                    float64
# total_deaths                          float64
# new_deaths                            float64
# new_deaths_smoothed                   float64
# total_cases_per_million               float64
# new_cases_per_million                 float64
# new_cases_smoothed_per_million        float64
# total_deaths_per_million              float64
# new_deaths_per_million                float64
# new_deaths_smoothed_per_million       float64
# reproduction_rate                     float64
# icu_patients                          float64
# icu_patients_per_million              float64
# hosp_patients                         float64
# ...

# %% [markdown]
# ## c.Info & describe of data in dataframe

# %%
#print("info of dataframe:\n",data.info())
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57394 entries, 0 to 57393
# Data columns (total 49 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   iso_code                            57071 non-null  object
#  1   continent                           56748 non-null  object
#  2   location                            57394 non-null  object
#  3   date                                57394 non-null  object
#  4   total_cases                         53758 non-null  float64
#  5   new_cases                           56465 non-null  float64
#  6   new_cases_smoothed                  55652 non-null  float64
#  7   total_deaths                        44368 non-null  float64
#  8   new_deaths                          56465 non-null  float64
#  9   new_deaths_smoothed                 55652 non-null  float64
#  10  total_cases_per_million             53471 non-null  float64
# ...

# %%
data.describe()
# Out:
#         total_cases      new_cases  new_cases_smoothed  total_deaths  \
# count  5.375800e+04   56465.000000        55652.000000  4.436800e+04
# mean   1.677974e+05    1953.576941         1920.431953  6.858639e+03
# std    1.693038e+06   18269.650340        17777.391785  5.578081e+04
# min    1.000000e+00   -8261.000000         -552.000000  1.000000e+00
# 25%    1.800000e+02       0.000000            0.857000  1.300000e+01
# 50%    2.070000e+03      14.000000           19.429000  8.400000e+01
# 75%    2.235675e+04     235.000000          245.286000  7.270000e+02
# max    5.515465e+07  646281.000000       584981.857000  1.328537e+06
#
#          new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  56465.000000         55652.000000             53471.000000
# mean      47.054317            46.835439              3139.099982
# std      390.853776           378.272794              6183.455260
# min    -1918.000000          -232.143000                 0.001000
# ...

# %% [markdown]
# # 3.Low Level undersatnding

# %% [markdown]
# ## a.find count of unique values in location column

# %%
print("count of unique vales in location column:",data["location"].nunique())
# Out:
# count of unique vales in location column: 216

# %% [markdown]
# ## b.find which continent has maximum frequency using values

# %%
print("continent has maximum frequnecy using values:",data["continent"].value_counts().idxmax())
# Out:
# continent has maximum frequnecy using values: Europe

# %% [markdown]
# ## c.find maximum & mean value in "total_cases "

# %%
print("maximum value in total_cases:",data["total_cases"].max())
print("mean value in total_cases:",data["total_cases"].mean())
# Out:
# maximum value in total_cases: 55154651.0
# mean value in total_cases: 167797.3688753302

# %% [markdown]
# ## d.find 25%,50%,& 75% quartile valuein total_deaths

# %%
print("25% of quartile value in total_deaths:",data["total_deaths"].quantile(0.25))
print("\n50% of quartile value in total_deaths:",data["total_deaths"].quantile(0.50))
print("\n75% of quartile value in total_deaths:",data["total_deaths"].quantile(0.75))
# Out:
# 25% of quartile value in total_deaths: 13.0
#
# 50% of quartile value in total_deaths: 84.0
#
# 75% of quartile value in total_deaths: 727.0

# %% [markdown]
# # e.find which continent has maximum human_development_index

# %%
data.groupby("continent")["human_development_index"].max().nlargest(1)
# Out:
# continent
# Europe    0.953
# Name: human_development_index, dtype: float64

# %%
data["human_development_index"].idxmax()
# Out:
# 38632

# %% [markdown]
# ## f.find which continent has minimum gdp_per_capita

# %%
data.groupby("continent")["gdp_per_capita"].min().nsmallest(1)
# Out:
# continent
# Africa    661.24
# Name: gdp_per_capita, dtype: float64

# %% [markdown]
# # 4.filter the dataframe with only this columns
#
#
#
# ['continent','location','date','total_cases','total_deaths','gdp_per_capita','human_development_index'] and update the data frame.

# %%
data=data[['continent','location','date','total_cases','total_deaths','gdp_per_capita','human_development_index']]

# %%
data
# Out:
#       continent       location      date  total_cases  total_deaths  \
# 0          Asia    Afghanistan  31/12/19          NaN           NaN
# 1          Asia    Afghanistan  01/01/20          NaN           NaN
# 2          Asia    Afghanistan  02/01/20          NaN           NaN
# 3          Asia    Afghanistan  03/01/20          NaN           NaN
# 4          Asia    Afghanistan  04/01/20          NaN           NaN
# ...         ...            ...       ...          ...           ...
# 57389       NaN  International  13/11/20        696.0           7.0
# 57390       NaN  International  14/11/20        696.0           7.0
# 57391       NaN  International  15/11/20        696.0           7.0
# 57392       NaN  International  16/11/20        696.0           7.0
# 57393       NaN  International  17/11/20        696.0           7.0
#
#        gdp_per_capita  human_development_index
# 0            1803.987                    0.498
# 1            1803.987                    0.498
# ...

# %% [markdown]
# # 5.Data cleaning

# %% [markdown]
# ## a. removing all duplicate observations

# %%
data=data.drop_duplicates()

# %% [markdown]
# ## b.find all missing values

# %%
data.isnull().sum()
# Out:
# continent                    646
# location                       0
# date                           0
# total_cases                 3636
# total_deaths               13026
# gdp_per_capita              7027
# human_development_index     8147
# dtype: int64

# %% [markdown]
# ## c. remove alll observations where continent column value is missing

# %%
data.dropna(subset=["continent"],inplace=True)

# %%
data.isnull().sum()
# Out:
# continent                      0
# location                       0
# date                           0
# total_cases                 3600
# total_deaths               12964
# gdp_per_capita              6704
# human_development_index     7501
# dtype: int64

# %% [markdown]
# ## d.fill all missing values with 0

# %%
data.fillna(0,inplace=True)
data.isnull().sum()
# Out:
# continent                  0
# location                   0
# date                       0
# total_cases                0
# total_deaths               0
# gdp_per_capita             0
# human_development_index    0
# dtype: int64

# %% [markdown]
# # 6.Data time format

# %% [markdown]
# ## a.convert date column in datetime fromat using pandas.to_datetime

# %%
data.dtypes
# Out:
# continent                   object
# location                    object
# date                        object
# total_cases                float64
# total_deaths               float64
# gdp_per_capita             float64
# human_development_index    float64
# dtype: object

# %%
data["date"]=pd.to_datetime(data["date"])
data.dtypes
# Out:
# continent                          object
# location                           object
# date                       datetime64[ns]
# total_cases                       float64
# total_deaths                      float64
# gdp_per_capita                    float64
# human_development_index           float64
# datetime format            datetime64[ns]
# dtype: object

# %% [markdown]
# ## b.create new column month after extracting fromn date column

# %%
data['month']=data['date'].dt.month
data[data['location']=='India']
# Out:
#       continent location       date  total_cases  total_deaths  \
# 24005      Asia    India 2019-12-31          0.0           0.0
# 24006      Asia    India 2020-01-01          0.0           0.0
# 24007      Asia    India 2020-02-01          0.0           0.0
# 24008      Asia    India 2020-03-01          0.0           0.0
# 24009      Asia    India 2020-04-01          0.0           0.0
# ...         ...      ...        ...          ...           ...
# 24323      Asia    India 2020-11-13    8728795.0      128668.0
# 24324      Asia    India 2020-11-14    8773479.0      129188.0
# 24325      Asia    India 2020-11-15    8814579.0      129635.0
# 24326      Asia    India 2020-11-16    8845127.0      130070.0
# 24327      Asia    India 2020-11-17    8874290.0      130519.0
#
#        gdp_per_capita  human_development_index datetime format  month
# 24005        6426.674                     0.64      2019-12-31     12
# ...

# %% [markdown]
# # 7.Data Aggregation:

# %% [markdown]
# ## a.find max value in all columns using groupby function on continent column
# tip: use reset_index() after applying groupby

# %%
data.groupby("continent").max().reset_index()
# Out:
#        continent                      location       date  total_cases  \
# 0         Africa                      Zimbabwe 2020-12-11     752269.0
# 1           Asia                         Yemen 2020-12-11    8874290.0
# 2         Europe                       Vatican 2020-12-11    1991233.0
# 3  North America  United States Virgin Islands 2020-12-11   11205486.0
# 4        Oceania             Wallis and Futuna 2020-12-11      27750.0
# 5  South America                     Venezuela 2020-12-11    5876464.0
#
#    total_deaths  gdp_per_capita  human_development_index datetime format  \
# 0       20314.0       26382.287                    0.797      2020-12-11
# 1      130519.0      116935.600                    0.933      2020-12-11
# 2       52147.0       94277.965                    0.953      2020-12-11
# 3      247220.0       54225.446                    0.926      2020-12-11
# 4         907.0       44648.710                    0.939      2020-12-11
# ...

# %% [markdown]
# ## b.store the result in a new  dataframe named by df_groupby
# (use df_groupby dataframe for all further analysis)

# %%
data_groupby=data.groupby("continent").max().reset_index()

# %%
data_groupby
# Out:
#        continent                      location       date  total_cases  \
# 0         Africa                      Zimbabwe 2020-12-11     752269.0
# 1           Asia                         Yemen 2020-12-11    8874290.0
# 2         Europe                       Vatican 2020-12-11    1991233.0
# 3  North America  United States Virgin Islands 2020-12-11   11205486.0
# 4        Oceania             Wallis and Futuna 2020-12-11      27750.0
# 5  South America                     Venezuela 2020-12-11    5876464.0
#
#    total_deaths  gdp_per_capita  human_development_index datetime format  \
# 0       20314.0       26382.287                    0.797      2020-12-11
# 1      130519.0      116935.600                    0.933      2020-12-11
# 2       52147.0       94277.965                    0.953      2020-12-11
# 3      247220.0       54225.446                    0.926      2020-12-11
# 4         907.0       44648.710                    0.939      2020-12-11
# ...

# %% [markdown]
# # 8. Feature Engineering

# %% [markdown]
# # a.create  a new feature "total_death_to total_cases" ratio to "total_deaths" columns to "total_cases"

# %%
data_groupby["total_death_to_total_columns"]=data_groupby["total_deaths"]/data_groupby["total_cases"]

# %%
data_groupby
# Out:
#        continent                      location       date  total_cases  \
# 0         Africa                      Zimbabwe 2020-12-11     752269.0
# 1           Asia                         Yemen 2020-12-11    8874290.0
# 2         Europe                       Vatican 2020-12-11    1991233.0
# 3  North America  United States Virgin Islands 2020-12-11   11205486.0
# 4        Oceania             Wallis and Futuna 2020-12-11      27750.0
# 5  South America                     Venezuela 2020-12-11    5876464.0
#
#    total_deaths  gdp_per_capita  human_development_index datetime format  \
# 0       20314.0       26382.287                    0.797      2020-12-11
# 1      130519.0      116935.600                    0.933      2020-12-11
# 2       52147.0       94277.965                    0.953      2020-12-11
# 3      247220.0       54225.446                    0.926      2020-12-11
# 4         907.0       44648.710                    0.939      2020-12-11
# ...

# %% [markdown]
# # 9.Data Visualization

# %% [markdown]
# ## a.perform univarient analysis on "gdp_per_captia" column by plotting

# %%
import warnings

warnings.filterwarnings("ignore")

# %%
displot1 = sns.distplot(data_groupby['gdp_per_capita'],color='green')
displot1.set(title='Univariate analysis on gdp_per_capita')
# Saving/exporting the figure
displot1.get_figure().savefig('9_a_1.jpg')

# %% [markdown]
# ## b.plot a scatter plot of total_cases & gdp_per_captia

# %%
scatterplot1=sns.scatterplot(x=data_groupby['total_cases'],y=data_groupby['gdp_per_capita'])
scatterplot1.set(title='Scatter plot of total_cases & gdp_per_capita')

# Saving/exporting the figure
scatterplot1.get_figure().savefig('9_b_1.jpg')

# %% [markdown]
# ## c. Plot Pairplot on df_groupby dataset.

# %%
pairplot1=sns.pairplot(data_groupby)
pairplot1.fig.suptitle('Pairplot on grouped data',y=1.05,fontsize=20)

#Saving/exporting the figure
pairplot1.savefig('9_c_1.jpg')

# %% [markdown]
# ## d. Plot a bar plot of 'continent' column with 'total_cases'.

# %%
barplot1=sns.catplot(data=data_groupby,x='continent',y='total_cases',kind='bar',aspect=1.5)
barplot1.set(title='Bar plot of continent with total_cases')
# Saving/exporting the figure
barplot1.savefig('9_d_1.jpg')

# %% [markdown]
# # 10. Save the df_groupby dataframe in your local drive using pandas.to_csv function

# %%
data_groupby.to_csv('COVID-19_grouped_data.csv')
